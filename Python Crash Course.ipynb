# %% [markdown]
# # Python crash course
# Let's learn Python 3!

# %% [markdown]
# This is a Python notebook. In here you can write:
#
#
# *   Text - Like this cell
#
# OR

# %%
Code - Like this cell

# %% [markdown]
# **Comments** <br>
# Comments are ignored.

# %%
# This is a one-line comment
"""
This
is
a
multi-line
comment
"""

# %% [markdown]
# **Creating variables** <br>
# Python is weakly-typed so you don't need to declare the variable type.

# %%
# integer
number = 10

# float
pi = 3.14

# string
name = 'John'

# boolean
ok = True

# %% [markdown]
# In Python we do not use semicolons or brackets.<br>
# **We use new lines instead of semicolons <br>
# We use identation blocks instead of brakets. **<br>
# ![alt text](https://i.redd.it/7v0a4ldssdq11.png)

# %% [markdown]
# **Printing variables** <br>
# The variables you need to print are passed to the 'print' function.

# %%
print(number)
print(pi)
print(name)
print(ok)
# Out:
# 10
# 3.14
# John
# True

# %% [markdown]
# #Input
# Using console input

# %%
name = input()
print(name)
# Out:
# John
# John

# %% [markdown]
# **Arithmetic Operations**<br>
# We use arithmetic operators to do math.

# %%
sum = 2 + 3
difference = 2 - 3
product = 2 * 3
division = 2 / 3
integer_division = 2 // 3
modulo = 5 % 3

print(sum, difference, product, division, integer_division, modulo)
# Out:
# 5 -1 6 0.6666666666666666 0 2

# %%
square = 3 ** 2
result = square + 3 * (4 - 5) / 3
print(square, result)
# Out:
# 9 8.0

# %% [markdown]
# **If Statements** <br>
# Again, indentation instead of brackets.

# %%
if 2 < 3:
  print('It Works!')
# Out:
# It Works!

# %% [markdown]
# You can add multiple conditions in a single if statement by using the 'or' or 'and' keywords.

# %%
if 5 > 4 or 2 > 3:
  print('I just need one condition to be true to work!')
  
if 5 > 4 and 2 > 3:
  print('I need both conditions to be true to work!')
# Out:
# I just need one condition to be true to work!

# %% [markdown]
# **Else and Elif** <br>
# If the condition in the 'if' statement is false, the program will execute the code inside the else block.

# %%
if 'John' == 'John' and 3 > 5:
  print('Expression evaluated as true')
else:
  print('Expression evaluated as false')
# Out:
# Expression evaluated as false

# %% [markdown]
# Use 'elif' instead of typing 'else if'.

# %%
age = 40

if age < 18:
  print('Kid')
elif age < 65:
  print('Adult')
else:
  print('Yoda')
# Out:
# Adult

# %% [markdown]
# **While loops** <br>
# The code inside the while block will be executed as long as the specified condition is true.

# %%
age = 0

while age < 18:
  print('Still a kid. I am now', age, 'years old.')
  age = age + 1
print('Doing the same stuff as before but legally')
# Out:
# Still a kid. I am now 0 years old.
# Still a kid. I am now 1 years old.
# Still a kid. I am now 2 years old.
# Still a kid. I am now 3 years old.
# Still a kid. I am now 4 years old.
# Still a kid. I am now 5 years old.
# Still a kid. I am now 6 years old.
# Still a kid. I am now 7 years old.
# Still a kid. I am now 8 years old.
# Still a kid. I am now 9 years old.
# Still a kid. I am now 10 years old.
# Still a kid. I am now 11 years old.
# Still a kid. I am now 12 years old.
# Still a kid. I am now 13 years old.
# Still a kid. I am now 14 years old.
# Still a kid. I am now 15 years old.
# Still a kid. I am now 16 years old.
# Still a kid. I am now 17 years old.
# Doing the same stuff as before but legally

# %% [markdown]
# **Lists**<br>
# Lists are used to store multiple variables. <br>
# List indexing starts at zero.

# %%
number = 10
pi = 3.14
name = 'John'
ok = True

list = [number, pi, name, ok]

print('Complete list:', list)
print('First element of list:', list[0])
# Out:
# Complete list: [10, 3.14, 'John', True]
# First element of list: 10

# %% [markdown]
# To get the length of a list we use the 'len' function.

# %%
length = len(list)
print(length)
# Out:
# 4

# %% [markdown]
# **For loops**<br>
# We use for loops to iterate through each member of a list.

# %%
for element in list:
  print(element)
# Out:
# 10
# 3.14
# John
# True

# %% [markdown]
# **Functions** <br>
# We use functions to run blocks without rewriting the code and cluttering our program.

# %%
def shout():
  print('Bucharest School of AI rocks!')

shout()
# Out:
# Bucharest School of AI rocks!

# %%
def make_square(input):
  return input ** 2

print(make_square(3))
# Out:
# 9

# %% [markdown]
# # Coding Challenge 1
# Write a short program which reads your name and greets you in a unique way!

# %% [markdown]
# # Coding Challenge 2
# Write a short program which reads your age and tells you how many years you have until reaching 100 years.

# %% [markdown]
# # Coding Challenge 3
# Write a short program which reads a number and tells you if it's even or odd.

# %% [markdown]
# # Coding Challenge 4
# Write a program that reads a phrase and prints it back 10 times

# %% [markdown]
# # Coding Challenge 5
# Write a program which reads a number from 1 to 7 and tells you what day of the week it is.
#
# ## Example
#
# **Input**
# ```
# 2
# ```
# **Output**
# ```
# Tuesday
# ```

# %% [markdown]
# # Getting started with libraries
# ## Importing a library

# %%
import numpy

# %%
import numpy as np

# %% [markdown]
# ## Operating with lists as Numpy arrays

# %%
list = [1, 2, 5, 2, 8, 6, 7]
np_array = np.array(list)

# %% [markdown]
# ## Aggregation

# %%
np.sum(np_array)
# Out:
# 26

# %%
np.min(np_array)
# Out:
# 1

# %%
np.max(np_array)
# Out:
# 8

# %%
np.mean(np_array)
# Out:
# 4.333333333333333

# %%
np.median(np_array)
# Out:
# 5.0

# %%
np.std(np_array)
# Out:
# 2.5555062599997598

# %% [markdown]
# ## Arithmetic Operations

# %%
np.multiply(list, 5)
# Out:
# array([ 5, 10, 25, 10, 40, 30, 35])

# %%
np.sqrt(np_array)
# Out:
# array([1.        , 1.41421356, 1.41421356, 2.23606798, 2.44948974,
#        2.64575131, 2.82842712])

# %%
np.log(np_array)
# Out:
# array([0.        , 0.69314718, 0.69314718, 1.60943791, 1.79175947,
#        1.94591015, 2.07944154])

# %%
np.dot(np_array, np_array)
# Out:
# 183

# %% [markdown]
# ## Sorting

# %%
np_array.sort()
print(np_array)
# Out:
# [1 2 2 5 6 7 8]

# %% [markdown]
# ## Array manipulation

# %%
np.append([1, 2, 3], [4, 5, 6])
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
np.reshape([1, 2, 3, 4], (2, 2))
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# # Coding Challenge 6

# %%
prices = [1.25, 12, 9.9, 10.5, 15, 12, 7, 8.5]

# %% [markdown]
# The above list contains the changing price of a product from an online store, **before a 20% tax is applied**. Print the difference between the highest price and the lowest price after the tax is applied, by using Numpy functions.

# %% [markdown]
# # Coding challange 7

# %%
new_prices = [2.35, 9.15, 8, 20]

# %% [markdown]
# Add the contents of the new list to the old list. Print the price average before and after adding the new values. How much did it change?

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Line Plots

# %%
plt.plot(prices)
plt.show()

# %% [markdown]
# ## Bar Plots

# %%
plt.bar("Maximum price",np.max(prices))
plt.bar("Minimum price", np.min(prices))
plt.bar("Average price", np.mean(prices))
plt.show()

# %% [markdown]
# ## Histogram

# %%
plt.hist(prices)
plt.show()

# %% [markdown]
# ## Scatter plots

# %%
height = [1.74, 1.85, 1.83, 1.62, 1.50, 1.92]
shoe_size = [38, 45, 44, 35, 32, 46]
plt.scatter(height, shoe_size)
plt.show()

# %% [markdown]
# #Files

# %% [markdown]
# In our case we need to download a dataset from the web. We will use the 'urllib' library to help us out.

# %%
from urllib.request import urlopen
data = urlopen("https://raw.githubusercontent.com/bucharestschoolofai/python_crash_course/master/train.csv")

# %% [markdown]
# Now, we have our raw file but we need Pandas to make Python able to interpret it.

# %%
import pandas as pd
data = pd.read_csv(data)
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
array = data.values
print(array)
# Out:
# [[1 0 3 ... 7.25 nan 'S']
#  [2 1 1 ... 71.2833 'C85' 'C']
#  [3 1 3 ... 7.925 nan 'S']
#  ...
#  [889 0 3 ... 23.45 nan 'S']
#  [890 1 1 ... 30.0 'C148' 'C']
#  [891 0 3 ... 7.75 nan 'Q']]

# %% [markdown]
# ## Coding Challange 8 - Titanic
# Find out what percent of the Titanic crew survived.

# %% [markdown]
# Using the 'array' variable:

# %% [markdown]
# Create a bar chart which shows how many people were on board by gender.

# %% [markdown]
# Create a histogram based on the ages of the passangers.

# %% [markdown]
# Create a visualization of your choice!

# %% [markdown]
# ## Coding Challange 9
